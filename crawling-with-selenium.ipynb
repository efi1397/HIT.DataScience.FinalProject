# %%
import time
import bs4
from bs4 import BeautifulSoup  
import pandas as pd
import scipy as sc
import numpy as np
import requests

# --- selenium libraries
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

# %%
def get_infinity_page_html_data(chromedriver_path="./chromedriver.exe", scroll_number=1, sleep_time=2):
    # Create selenium driver
    s = Service(chromedriver_path)
    driver = webdriver.Chrome(service=s)    
    driver.get(url)
    
    for i in range(1,scroll_number):
        print(f"scroll_number: {i}")
        driver.execute_script("window.scrollTo(1,50000)")
        time.sleep(sleep_time)
    html_data = driver.page_source
    driver.close()
    
    return html_data

# %%
def extract_medium_articles_from_HTML_data(html_data):
    # Extract articles from HTML data 
    soup = BeautifulSoup(html_data, 'html.parser')    
    articles = soup.find_all("article")
    print(f"Number of articles: {len(articles)}")
    
    return articles

# %%
def create_df_from_articles(articles,category):    
    # Create a lists for df
    categories = []
    headers = []
    subheaders= []
        
    for article in articles:            
        categories.append(category)        
        headers.append(article.find("h2").get_text())
        subheaders.append(article.find("p").get_text())    
    
    #TODO: Append link list
    return pd.DataFrame(
        {"category": categories,  
         "header": headers, 
         "subheader": subheaders})

# %%
#here you can add more categories
categories = ["technology","politics", "sport"]
    
for category in categories: 
    url = f"https://medium.com/tag/{category}/latest"    
    html_data = get_infinity_page_html_data(scroll_number=4)
    articles = extract_medium_articles_from_HTML_data(html_data)
    df = create_df_from_articles(articles, category)
    print(df.shape)
    print(df)
    print()
# Out:
# scroll_number: 1
# scroll_number: 2
# scroll_number: 3
# Number of articles: 39
# (39, 3)
#       category                                             header  \
# 0   technology  How I Started a Company with my Best Friend in...
# 1   technology                    A New Network for Smart Devices
# 2   technology                Useful online courses that are free
# 3   technology       How to Choose the Right Cloud Infrastructure
# 4   technology  Elon Musk Just Bought Twitter. What Changes Sh...
# 5   technology                              A Wake-Up Call on GPS
# 6   technology                                  issue 233–4.25.22
# 7   technology                         Virtual reality needs Halo
# 8   technology  10 Online Safety Tips You Should Know If You T...
# 9   technology  Free Speech Haters, You Brought This Upon Your...
# 10  technology  6 Free Google Certifications For Self-Taught D...
# 11  technology       IOSTSWAPファーム、エントロバース・エコシステムに初のクロスチェーンDeFiが登場
# ...
